# %%
# !pip install easyocr
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 24.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 908.3/908.3 kB 44.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.0/146.0 kB 15.9 MB/s eta 0:00:00
# ...

# %%
import os
import easyocr
from PIL import Image

# Path to the folder containing your JPG images
source_folder = '/content/sample_data/source1/'

# Path to the folder where you want to store the extracted text files
output_folder = '/content/sample_data/Sachin2/'

# Initialize the EasyOCR reader
reader = easyocr.Reader(['en'])

# Loop through all JPG files in the source folder
for filename in os.listdir(source_folder):
    if filename.endswith('.jpg'):
        image_path = os.path.join(source_folder, filename)
        img = Image.open(image_path)

        # Perform OCR to extract text from the image
        extracted_text = reader.readtext(image_path, detail=0)

        # Create a text file with the same name as the image in the output folder
        output_file_path = os.path.join(output_folder, os.path.splitext(filename)[0] + '.txt')

        # Write the extracted text to the text file
        with open(output_file_path, 'w') as text_file:
            text_file.write('\n'.join(extracted_text))

        print(f"Text extracted from {filename} and saved to {output_file_path}")

print('Text extraction from all images is complete.')
# Out:
# WARNING:easyocr.easyocr:Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Text extracted from 156.jpg and saved to /content/sample_data/Sachin2/156.txt
# Text extracted from 13.jpg and saved to /content/sample_data/Sachin2/13.txt
# Text extracted from 139.jpg and saved to /content/sample_data/Sachin2/139.txt
# Text extracted from 97.jpg and saved to /content/sample_data/Sachin2/97.txt
# Text extracted from 167.jpg and saved to /content/sample_data/Sachin2/167.txt
# Text extracted from 116.jpg and saved to /content/sample_data/Sachin2/116.txt
# Text extracted from 29.jpg and saved to /content/sample_data/Sachin2/29.txt
# Text extracted from 388.jpg and saved to /content/sample_data/Sachin2/388.txt
# Text extracted from 251.jpg and saved to /content/sample_data/Sachin2/251.txt
# Text extracted from 438.jpg and saved to /content/sample_data/Sachin2/438.txt
# ...

# %%
import os
import csv

# Path to the folder containing your text files
folder_path = '/content/sample_data/Sachin2/'

# Path to the output CSV file
output_file_path = '/content/sample_data/sachin/combined.csv'

# Initialize a list to store the data
data = []

# Loop through all text files in the folder
for filename in os.listdir(folder_path):
    if filename.endswith('.txt'):
        file_path = os.path.join(folder_path, filename)

        # Read the content of the current text file
        with open(file_path, 'r') as file:
            file_content = file.read()

        # Append the file name and its content to the data list
        data.append([filename, file_content])

# Write the data to the output CSV file
with open(output_file_path, 'w', newline='') as output_file:
    csv_writer = csv.writer(output_file)
    csv_writer.writerow(['File Name', 'Content'])
    csv_writer.writerows(data)

print(f'Combined CSV file saved at {output_file_path}')
# Out:
# Combined CSV file saved at /content/sample_data/sachin/combined.csv

# %%
import pandas as pd

# Path to the input CSV file
input_csv_file = '/content/sample_data/sachin/combined.csv'

# Path to the output Excel file
output_excel_file = '/content/sample_data/sachin/output.xlsx'

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(input_csv_file)

# Create an Excel writer object
writer = pd.ExcelWriter(output_excel_file, engine='xlsxwriter')

# Convert the DataFrame to an Excel sheet
df.to_excel(writer, sheet_name='Sheet1', index=False)

# Save the Excel file
writer.save()

print(f'CSV file "{input_csv_file}" converted to Excel file "{output_excel_file}"')
# Out:
# CSV file "/content/sample_data/sachin/combined.csv" converted to Excel file "/content/sample_data/sachin/output.xlsx"
# <ipython-input-13-3976ae2dbfba>:19: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   writer.save()

# %%
pip install XlsxWriter
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.3/154.3 kB 2.4 MB/s eta 0:00:00
# ...
